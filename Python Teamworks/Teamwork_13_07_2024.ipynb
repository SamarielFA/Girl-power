# %% [markdown]
# TEAMWORK 13.07.2024

# %% [markdown]
# To complete the tasks use 'transaction_dataset.csv'
#
#
# Task 1: Create a bar chart that shows the count of transactions for each unique value in the 'Gender' column (including NaN values). - easy

# %%
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('/content/transaction_dataset.csv')

df5 = dataset['Gender'].value_counts(dropna=False)

plt.figure(figsize=(6, 4))
df5.plot(kind='bar', color=['blue', 'orange', 'green'])
plt.title('Customer count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count of Customers')
plt.xticks(rotation=0, ha='center')
plt.grid(True)
plt.show()

# %% [markdown]
# Task 2: Create a horizontal bar chart that shows the top 5 most frequent names in the DataFrame, based on the 'name' column. (First, create a grouped DataFrame (name_df), then filter it using iloc, and finally create the visualization.) -medium

# %%
name_df = dataset['Name'].value_counts(dropna=False).reset_index().head()
name_df
# Out:
#           Name  count
# 0      Michael   1167
# 1        David    761
# 2         John    749
# 3        James    730
# 4  Christopher    711

# %%
plt.barh(name_df['Name'], name_df['count'])
plt.title('5 MOST FREQUENT CUSTOMER NAMES')
plt.xlabel('Count')
plt.ylabel('Name')
plt.show()

# %% [markdown]
# Task 3: Create a filtered DataFrame that includes Category == 'Clothing' and Gender == 'M'. How many rows are there in this filtered DataFrame? Format the result as follows: The filtered DataFrame has XXXX rows. - hard

# %%
filtered_df = dataset[(dataset['Category'] == 'Clothing') & (dataset['Gender'] == 'M')].value_counts(dropna=False).reset_index()
filtered_df.head()
# Out:
#    Customer ID       Name    Surname Gender   Birthdate  Transaction Amount  \
# 0           54  Christian  Hernandez      M  25/10/1981              166.30
# 1       670415       Ryan     Taylor      M  20/10/2001               55.66
# 2       668457      Molly  Alexander      M  23/10/1991              211.45
# 3       668635    William     Franco      M  01/11/1954               80.81
# 4       668789     Steven    Spencer      M  01/11/1952              201.05
#
#          Date                  Merchant Name  Category  count
# 0  25/07/2023                Torres and Sons  Clothing      1
# 1  07/01/2023                        Lee Inc  Clothing      1
# 2  27/04/2023      Morales, Williams and Cox  Clothing      1
# 3  16/04/2023               Wilson-Gutierrez  Clothing      1
# 4  27/02/2023  Gonzalez, Rodriguez and Riley  Clothing      1

# %%
print(f'The filtered DataFrame has {filtered_df.shape[0]} rows.')
# Out:
# The filtered DataFrame has 3738 rows.

# %%
brand_df = dataset[(dataset['Category'] == 'Clothing') & (dataset['Gender'] == 'M') & (dataset['Date']=='01/01/2023')].value_counts(dropna=False).reset_index()
brand_df
print(f'interesting fact, that {brand_df.shape[0]} Men bought clothes on January 1, 2023 however none of them has birthday that day 🤣')
# Out:
# interesting fact, that 18 Men bought clothes on January 1, 2023 however none of them has birthday that day 🤣
